# %%
import pandas as pd
import numpy as np

# %%
pit_data = "datasets/2007-2022-PIT-Counts-by-CoC.xlsx"
col_data = "datasets/cost-of-living-database.xlsx"
uer_data = "datasets/laucnty21.xlsx"
ac

# %%
pd.set_option('display.max_rows', None)

# %%
pit = pd.read_excel(pit_data, sheet_name="2022")

# %%
display(pit)
# Out:
#                                             CoC Number  \
# 0                                               AK-500
# 1                                               AK-501
# 2                                               AL-500
# 3                                               AL-501
# 4                                               AL-502
# 5                                               AL-503
# 6                                               AL-504
# 7                                               AL-505
# 8                                               AL-506
# 9                                               AL-507
# 10                                              AR-500
# 11                                              AR-501
# 12                                              AR-503
# 13                                              AR-505
# 14                                              AR-508
# 15                                              AZ-500
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
city_dict = {}

for city in weirdlist[:100]:
    print(city)
    city_dict[city] = geolocator.geocode(city).raw['display_name'].split(',')[1].strip()
# Out:
# Bethel, Connecticut
# Bridgeport, Connecticut
# Brookfield, Connecticut
# Danbury, Connecticut
# Darien, Connecticut
# Easton, Connecticut
# Fairfield, Connecticut
# Greenwich, Connecticut
# Monroe, Connecticut
# New Canaan, Connecticut
# New Fairfield, Connecticut
# Newtown, Connecticut
# Norwalk, Connecticut
# Redding, Connecticut
# Ridgefield, Connecticut
# Shelton, Connecticut
# Sherman, Connecticut
# Stamford, Connecticut
# Stratford, Connecticut
# Trumbull, Connecticut
# Weston, Connecticut
# Westport, Connecticut
# Wilton, Connecticut
# Avon, Connecticut
# Berlin, Connecticut
# Bloomfield, Connecticut
# Bristol, Connecticut
# Burlington, Connecticut
# Canton, Connecticut
# East Granby, Connecticut
# East Hartford, Connecticut
# East Windsor, Connecticut
# Enfield, Connecticut
# Farmington, Connecticut
# Glastonbury, Connecticut
# Granby, Connecticut
# Hartford, Connecticut
# Hartland, Connecticut
# Manchester, Connecticut
# Marlborough, Connecticut
# New Britain, Connecticut
# ...

# %%
city_dict
# Out:
# {'Bethel, Connecticut': 'Western Connecticut COG',
#  'Bridgeport, Connecticut': 'Greater Bridgeport COG',
#  'Brookfield, Connecticut': 'Western Connecticut COG',
#  'Danbury, Connecticut': 'Western Connecticut COG',
#  'Darien, Connecticut': 'Western Connecticut COG',
#  'Easton, Connecticut': 'Greater Bridgeport COG',
#  'Fairfield, Connecticut': 'Greater Bridgeport COG',
#  'Greenwich, Connecticut': 'Western Connecticut COG',
#  'Monroe, Connecticut': 'Greater Bridgeport COG',
#  'New Canaan, Connecticut': 'Western Connecticut COG',
#  'New Fairfield, Connecticut': 'Western Connecticut COG',
#  'Newtown, Connecticut': 'Western Connecticut COG',
#  'Norwalk, Connecticut': 'Western Connecticut COG',
#  'Redding, Connecticut': 'Western Connecticut COG',
#  'Ridgefield, Connecticut': 'Western Connecticut COG',
#  'Shelton, Connecticut': 'Naugatuck Valley COG',
#  'Sherman, Connecticut': 'Western Connecticut COG',
#  'Stamford, Connecticut': 'Western Connecticut COG',
# ...

# %%
geolocator.geocode("Bethel, Connecticut").raw
# Out:
# {'place_id': 299486460,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 11085823,
#  'boundingbox': ['41.349728', '41.395742', '-73.435021', '-73.385161'],
#  'lat': '41.372643',
#  'lon': '-73.412668',
#  'display_name': 'Bethel, Western Connecticut COG, Connecticut, 06801, United States',
#  'class': 'boundary',
#  'type': 'census',
#  'importance': 0.6157799882286896}

# %%
a = geolocator.geocode("Bridgeport, Connecticut").raw

# %%
a
# Out:
# {'place_id': 299481803,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 11049559,
#  'boundingbox': ['41.1399013', '41.2296213', '-73.2440717', '-73.1537198'],
#  'lat': '41.1670412',
#  'lon': '-73.2048348',
#  'display_name': 'Bridgeport, Greater Bridgeport COG, Connecticut, United States',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.757321915821912,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}

# %%
a['display_name'].split(',')[2].strip()
# Out:
# 'Connecticut'

# %%
location = geolocator.reverse(geolocator.geocode("Kodiak Island Borough, AK").point)

line = location.address
line
# Out:
# 'Kodiak Island, Alaska, United States'

# %%
line
# Out:
# '1, Baker Hollow Road, Pomfret, Northeastern Connecticut COG, Connecticut, 06259, United States'

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
    
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))
