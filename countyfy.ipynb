# %%
import re
import json

# %%
with open("tools/state_codes.json", 'r') as f:
    state_codes = json.load(f)

# %%
all_weird = ['Bethel, Connecticut', 'Bridgeport, Connecticut', 'Brookfield, Connecticut', 'Danbury, Connecticut', 'Darien, Connecticut', 'Easton, Connecticut', 'Fairfield, Connecticut', 'Greenwich, Connecticut', 'Monroe, Connecticut', 'New Canaan, Connecticut', 'New Fairfield, Connecticut', 'Newtown, Connecticut', 'Norwalk, Connecticut', 'Redding, Connecticut', 'Ridgefield, Connecticut', 'Shelton, Connecticut', 'Sherman, Connecticut', 'Stamford, Connecticut', 'Stratford, Connecticut', 'Trumbull, Connecticut', 'Weston, Connecticut', 'Westport, Connecticut', 'Wilton, Connecticut', 'Avon, Connecticut', 'Berlin, Connecticut', 'Bloomfield, Connecticut', 'Bristol, Connecticut', 'Burlington, Connecticut', 'Canton, Connecticut', 'East Granby, Connecticut', 'East Hartford, Connecticut', 'East Windsor, Connecticut', 'Enfield, Connecticut', 'Farmington, Connecticut', 'Glastonbury, Connecticut', 'Granby, Connecticut', 'Hartford, Connecticut', 'Hartland, Connecticut', 'Manchester, Connecticut', 'Marlborough, Connecticut', 'New Britain, Connecticut', 'Newington, Connecticut', 'Plainville, Connecticut', 'Rocky Hill, Connecticut', 'Simsbury, Connecticut', 'Southington, Connecticut', 'South Windsor, Connecticut', 'Suffield, Connecticut', 'West Hartford, Connecticut', 'Wethersfield, Connecticut', 'Windsor, Connecticut', 'Windsor Locks, Connecticut', 'Barkhamsted, Connecticut', 'Bethlehem, Connecticut', 'Bridgewater, Connecticut', 'Canaan, Connecticut', 'Colebrook, Connecticut', 'Cornwall, Connecticut', 'Goshen, Connecticut', 'Harwinton, Connecticut', 'Kent, Connecticut', 'Litchfield, Connecticut', 'Morris, Connecticut', 'New Hartford, Connecticut', 'New Milford, Connecticut', 'Norfolk, Connecticut', 'North Canaan, Connecticut', 'Plymouth, Connecticut', 'Roxbury, Connecticut', 'Salisbury, Connecticut', 'Sharon, Connecticut', 'Thomaston, Connecticut', 'Torrington, Connecticut', 'Warren, Connecticut', 'Washington, Connecticut', 'Watertown, Connecticut', 'Winchester, Connecticut', 'Woodbury, Connecticut', 'Chester, Connecticut', 'Clinton, Connecticut', 'Cromwell, Connecticut', 'Deep River, Connecticut', 'Durham, Connecticut', 'East Haddam, Connecticut', 'East Hampton, Connecticut', 'Essex, Connecticut', 'Haddam, Connecticut', 'Killingworth, Connecticut', 'Middlefield, Connecticut', 'Middletown, Connecticut', 'Old Saybrook, Connecticut', 'Portland, Connecticut', 'Westbrook, Connecticut', 'Ansonia, Connecticut', 'Beacon Falls, Connecticut', 'Bethany, Connecticut', 'Branford, Connecticut', 'Cheshire, Connecticut', 'Derby, Connecticut', 'East Haven, Connecticut', 'Guilford, Connecticut', 'Hamden, Connecticut', 'Madison, Connecticut', 'Meriden, Connecticut', 'Middlebury, Connecticut', 'Milford, Connecticut', 'Naugatuck, Connecticut', 'New Haven, Connecticut', 'North Branford, Connecticut', 'North Haven, Connecticut', 'Orange, Connecticut', 'Oxford, Connecticut', '
Rehoboth, Massachusetts', 'Seekonk, Massachusetts', 'Somerset, Massachusetts', 'Swansea, Massachusetts', 'Taunton, Massachusetts', 'Westport, Massachusetts', 'Aquinnah, Massachusetts', 'Chilmark, Massachusetts', 'Edgartown, Massachusetts', 'Gosnold, Massachusetts', 'Oak Bluffs, Massachusetts', 'Tisbury, Massachusetts', 'West Tisbury, Massachusetts', 'Amesbury Town, Massachusetts', 'Andover, Massachusetts', 'Beverly, Massachusetts', 'Boxford, Massachusetts', 'Danvers, Massachusetts', 'Essex, Massachusetts', 'Georgetown, Massachusetts', 'Gloucester, Massachusetts', 'Groveland, Massachusetts', 'Hamilton, Massachusetts', 'Haverhill, Massachusetts', 'Ipswich, Massachusetts', 'Lawrence, Massachusetts', 'Lynn, Massachusetts', 'Lynnfield, Massachusetts', 'Manchester-by-the-Sea, Massachusetts', 'Marblehead, Massachusetts', 'Merrimac, Massachusetts', 'Methuen, Massachusetts', 'Middleton, Massachusetts', 'Nahant, Massachusetts', 'Newbury, Massachusetts', 'Newburyport, Massachusetts', 'North Andover, Massachusetts', 'Peabody, Massachusetts', 'Rockport, Massachusetts', 'Rowley, Massachusetts', 'Salem, Massachusetts', 'Salisbury, Massachusetts', 'Saugus, Massachusetts', 'Swampscott, Massachusetts', 'Topsfield, Massachusetts', 'Wenham, Massachusetts', 'West Newbury, Massachusetts', 'Ashfield, Massachusetts', 'Bernardston, Massachusetts', 'Buckland, Massachusetts', 'Charlemont, Massachusetts', 'Colrain, Massachusetts', 'Conway, Massachusetts', 'Deerfield, Massachusetts', 'Erving, Massachusetts', 'Gill, Massachusetts', 'Greenfield Town, Massachusetts', 'Hawley, Massachusetts', 'Heath, Massachusetts', 'Leverett, Massachusetts', 'Leyden, Massachusetts', 'Monroe, Massachusetts', 'Montague, Massachusetts', 'New Salem, Massachusetts', 'Northfield, Massachusetts', 'Orange, Massachusetts', 'Rowe, Massachusetts', 'Shelburne, Massachusetts', 'Shutesbury, Massachusetts', 'Sunderland, Massachusetts', 'Warwick, Massachusetts', 'Wendell, Massachusetts', 'Whately, Massachusetts', 'Agawam Town, Massachusetts', 'Blandford, Massachusetts', 'Brimfield, Massachusetts', 'Chester, Massachusetts', 'Chicopee, Massachusetts', 'East Longmeadow, Massachusetts', 'Granville, Massachusetts', 'Hampden, Massachusetts', 'Holland, Massachusetts', 'Holyoke, Massachusetts', 'Longmeadow, Massachusetts', 'Ludlow, Massachusetts', 'Monson, Massachusetts', 'Montgomery, Massachusetts', 'Palmer Town, Massachusetts', 'Russell, Massachusetts', 'Southwick, Massachusetts', 'Springfield, Massachusetts', 'Tolland, Massachusetts', 'Wales, Massachusetts', 'Westfield, Massachusetts', 'West Springfield Town, Massachusetts', 'Wilbraham, Massachusetts', 'Amherst, Massachusetts', 'Belchertown, Massachusetts', 'Chesterfield, Massachusetts', 'Cummington, Massachusetts', 'Easthampton Town, Massachusetts', 'Goshen, Massachusetts', 'Granby, Massachusetts', 'Hadley, Massachusetts', 'Hatfield, Massachusetts', 'Huntington, Massachusetts', 'Middlefield, Massachusetts', 'Northampton, Massachusetts', 'Pelham, Massachusetts', 'Plainfield, Massachusetts', 'Southampton, Massachusetts', 'South Hadley, Massachusetts', 'Ware, Massachusetts', 'Westhampton, Massachusetts', 'Williamsburg, Massachusetts', 'Worthington, Massachusetts', 'Acton, Massachusetts', 'Arlington, Massachusetts', 'Ashby, Massachusetts', 'Ashland, Massachusetts', 'Ayer, Massachusetts', 'Bedford, Massachusetts', 'Belmont, Massachusetts', 'Billerica, Massachusetts', 'Boxborough, Massachusetts', 'Burlington, Massachusetts', 'Cambridge, Massachusetts', 'Carlisle, Massachusetts', 'Chelmsford, Massachusetts', 'Concord, Massachusetts', 'Dracut, Massachusetts', 'Dunstable, Massachusetts', 'Everett, Massachusetts', 'Framingham, Massachusetts', 'Groton, Massachusetts', 'Holliston, Massachusetts', 'Hopkinton, Massachusetts', 'Hudson, Massachusetts', 'Lexington, Massachusetts', 'Lincoln, Massachusetts', 'Littleton, Massachusetts', 'Lowell, Massachusetts', 'Malden, Massachusetts', 'Marlborough, Massachusetts', 'Maynard, Massachusetts', 'Medford, Massachusetts', 'Melrose, Massachusetts', 'Natick, Massachusetts', 'Newton, Massachusetts', 'North Reading, Massachusetts', 'Pepperell, Massachusetts', 'Reading, Massachusetts', 'Sherborn, Massachusetts', 'Shirley, Massachusetts', 'Somerville, Massachusetts', 'Stoneham, Massachusetts', 'Stow, Massachusetts', 'Sudbury, Massachusetts', 'Tewksbury, Massachusetts', 'Townsend, Massachusetts', 'Tyngsborough, Massachusetts', 'Wakefield, Massachusetts', 'Waltham, Massachusetts', 'Watertown, Massachusetts', 'Wayland, Massachusetts', 'Westford, Massachusetts', 'Weston, Massachusetts', 'Wilmington, Massachusetts', 'Winchester, Massachusetts', 'Woburn, Massachusetts', 'Nantucket, Massachusetts', 'Avon, Massachusetts', 'Bellingham, Massachusetts', 'Braintree Town, Massachusetts', 'Brookline, Massachusetts', 'Canton, Massachusetts', 'Cohasset, Massachusetts', 'Dedham, Massachusetts', 'Dover, Massachusetts', 'Foxborough, Massachusetts', 'Franklin Town, Massachusetts', 'Holbrook, Massachusetts', 'Medfield, Massachusetts', 'Medway, Massachusetts', 'Millis, Massachusetts', 'Milton, Massachusetts', 'Needham, Massachusetts', 'Norfolk, Massachusetts', 'Norwood, Massachusetts', 'Plainville, Massachusetts', 'Quincy, Massachusetts', 'Randolph, Massachusetts', 'Sharon, Massachusetts', 'Stoughton, Massachusetts', 'Walpole, Massachusetts', 'Wellesley, Massachusetts', 'Westwood, Massachusetts', 'Weymouth Town, Massachusetts', 'Wrentham, Massachusetts', 'Abington, Massachusetts', 'Bridgewater, Massachusetts', 'Brockton, Massachusetts', 'Carver, Massachusetts', 'Duxbury, Massachusetts', 'East Bridgewater, Massachusetts', 'Halifax, Massachusetts', 'Hanover, Massachusetts', 'Hanson, Massachusetts', 'Hingham, Massachusetts', 'Hull, Massachusetts', 'Kingston, Massachusetts', 'Lakeville, Massachusetts', 'Marion, Massachusetts', 'Marshfield, Massachusetts', 'Mattapoisett, Massachusetts', 'Middleborough, Massachusetts', 'Norwell
ermont', 'Marshfield, Vermont', 'Middlesex, Vermont', 'Montpelier, Vermont', 'Moretown, Vermont', 'Northfield, Vermont', 'Plainfield, Vermont', 'Roxbury, Vermont', 'Waitsfield, Vermont', 'Warren, Vermont', 'Waterbury, Vermont', 'Woodbury, Vermont', 'Worcester, Vermont', 'Athens, Vermont', 'Brattleboro, Vermont', 'Brookline, Vermont', 'Dover, Vermont', 'Dummerston, Vermont', 'Grafton, Vermont', 'Guilford, Vermont', 'Halifax, Vermont', 'Jamaica, Vermont', 'Londonderry, Vermont', 'Marlboro, Vermont', 'Newfane, Vermont', 'Putney, Vermont', 'Rockingham, Vermont', 'Somerset, Vermont', 'Stratton, Vermont', 'Townshend, Vermont', 'Vernon, Vermont', 'Wardsboro, Vermont', 'Westminster, Vermont', 'Whitingham, Vermont', 'Wilmington, Vermont', 'Windham, Vermont', 'Andover, Vermont', 'Baltimore, Vermont', 'Barnard, Vermont', 'Bethel, Vermont', 'Bridgewater, Vermont', 'Cavendish, Vermont', 'Chester, Vermont', 'Hartford, Vermont', 'Hartland, Vermont', 'Ludlow, Vermont', 'Norwich, Vermont', 'Plymouth, Vermont', 'Pomfret, Vermont', 'Reading, Vermont', 'Rochester, Vermont', 'Royalton, Vermont', 'Sharon, Vermont', 'Springfield, Vermont', 'Stockbridge, Vermont', 'Weathersfield, Vermont', 'Weston, Vermont', 'West Windsor, Vermont', 'Windsor, Vermont', 'Woodstock, Vermont', 'Alexandria, Virginia', 'Bedford, Virginia', 'Bristol, Virginia', 'Buena Vista, Virginia', 'Charlottesville, Virginia', 'Chesapeake, Virginia', 'Colonial Heights, Virginia', 'Covington, Virginia', 'Danville, Virginia', 'Emporia, Virginia', 'Fairfax, Virginia', 'Falls Church, Virginia', 'Franklin, Virginia', 'Fredericksburg, Virginia', 'Galax, Virginia', 'Hampton, Virginia', 'Harrisonburg, Virginia', 'Hopewell, Virginia', 'Lexington, Virginia', 'Lynchburg, Virginia', 'Manassas, Virginia', 'Manassas Park, Virginia', 'Martinsville, Virginia', 'Newport News, Virginia', 'Norfolk, Virginia', 'Norton, Virginia', 'Petersburg, Virginia', 'Poquoson, Virginia', 'Portsmouth, Virginia', 'Radford, Virginia', 'Richmond, Virginia', 'Roanoke, Virginia', 'Salem, Virginia', 'Staunton, Virginia', 'Suffolk, Virginia', 'Virginia Beach, Virginia', 'Waynesboro, Virginia', 'Williamsburg, Virginia', 'Winchester, Virginia']

# %%
ct_cities = [ct for ct in all_weird if ct.split()[-1] == "Connecticut"]
ct_cities
# Out:
# []

# %%
ct_county = '''Fairfield County
Bethel	Bridgeport	Brookfield	Danbury	Darien
Easton	Fairfield	Greenwich	Monroe	New Canaan
New Fairfield	Newtown	Norwalk	Redding	Ridgefield
Shelton	Sherman	Stamford	Stratford	Trumbull
Weston	Westport	Wilton	 	

Hartford County
Avon	Berlin	Bloomfield	Bristol	Burlington
Canton	East Granby	East Hartford	East Windsor	Enfield
Farmington	Glastonbury	Granby	Hartford	Hartland
Manchester	Marlborough	New Britain	Newington	Plainville
Rocky Hill	Simsbury	Southington	South Windsor	Suffield
West Hartford	Wethersfield	Windsor	Windsor Locks	 

Litchfield County
Barkhamsted	Bethlehem	Bridgewater	Canaan	Colebrook
Cornwall	Goshen	Harwinton	Kent	Litchfield
Morris	New Hartford	New Milford	Norfolk	North Canaan
Plymouth	Roxbury	Salisbury	Sharon	Thomaston
Torrington	Warren	Washington	Watertown	Winchester
Woodbury	 	 	 	 

Middlesex County
Chester	Clinton	Cromwell	Deep River	Durham
East Haddam	East Hampton	Essex	Haddam	Killingworth
Middlefield	Middletown	Old Saybrook	Portland	Westbrook

New Haven County
Ansonia	Beacon Falls	Bethany	Branford	Cheshire
Derby	East Haven	Guilford	Hamden	Madison
Meriden	Middlebury	Milford	Naugatuck	New Haven
North Branford	North Haven	Orange	Oxford	Prospect
Seymour	Southbury	Wallingford	Waterbury	West Haven
Wolcott	Woodbridge	 	 	 

New London County
Bozrah	Colchester	East Lyme	Franklin	Griswold
Groton	Lebanon	Ledyard	Lisbon	Lyme
Montville	New London	North Stonington	Norwich	Old Lyme
Preston	Salem	Sprague	Stonington	Voluntown
Waterford	 	 	 	 

Tolland County
Andover	Bolton	Columbia	Coventry	Ellington
Hebron	Mansfield	Somers	Stafford	Tolland
Union	Vernon	Willington	 	 

Windham County
Ashford	Brooklyn	Canterbury	Chaplin	Eastford
Hampton	Killingly	Plainfield	Pomfret	Putnam
Scotland	Sterling	Thompson	Windham	Woodstock
'''

# %%
city_to_county = {}

# %%
ct_county_list = ct_county.split("\n\n")
for county in ct_county_list:
    split = re.split("\n|\t", county)
    print
    county = split[0]
    split = split[1:]
    for ct in split:
        if (ct.strip() == ""):
            continue
        city_to_county[(ct, "CT")] = county

# %%
city_to_county
# Out:
# {('Bethel', 'CT'): 'Fairfield County',
#  ('Bridgeport', 'CT'): 'Fairfield County',
#  ('Brookfield', 'CT'): 'Fairfield County',
#  ('Danbury', 'CT'): 'Fairfield County',
#  ('Darien', 'CT'): 'Fairfield County',
#  ('Easton', 'CT'): 'Fairfield County',
#  ('Fairfield', 'CT'): 'Fairfield County',
#  ('Greenwich', 'CT'): 'Fairfield County',
#  ('Monroe', 'CT'): 'Fairfield County',
#  ('New Canaan', 'CT'): 'Fairfield County',
#  ('New Fairfield', 'CT'): 'Fairfield County',
#  ('Newtown', 'CT'): 'Fairfield County',
#  ('Norwalk', 'CT'): 'Fairfield County',
#  ('Redding', 'CT'): 'Fairfield County',
#  ('Ridgefield', 'CT'): 'Fairfield County',
#  ('Shelton', 'CT'): 'Fairfield County',
#  ('Sherman', 'CT'): 'Fairfield County',
#  ('Stamford', 'CT'): 'Fairfield County',
#  ('Stratford', 'CT'): 'Fairfield County',
#  ('Trumbull', 'CT'): 'Fairfield County',
#  ('Weston', 'CT'): 'Fairfield County',
#  ('Westport', 'CT'): 'Fairfield County',
#  ('Wilton', 'CT'): 'Fairfield County',
# ...

# %%
for town in ct_cities:
    if (town.split(",")[0], "CT") not in city_to_county:
        print(town.split(",")[0])

# %%
all_weird = [ct for ct in all_weird if ct.split()[-1] != "Connecticut"]
all_weird
# Out:
# ['District of, District of Columbia',
#  'Baltimore, Maryland',
#  'St. Louis, Missouri',
#  'Carson, Nevada',
#  'Alexandria, Virginia',
#  'Bedford, Virginia',
#  'Bristol, Virginia',
#  'Buena Vista, Virginia',
#  'Charlottesville, Virginia',
#  'Chesapeake, Virginia',
#  'Colonial Heights, Virginia',
#  'Covington, Virginia',
#  'Danville, Virginia',
#  'Emporia, Virginia',
#  'Fairfax, Virginia',
#  'Falls Church, Virginia',
#  'Franklin, Virginia',
#  'Fredericksburg, Virginia',
#  'Galax, Virginia',
#  'Hampton, Virginia',
#  'Harrisonburg, Virginia',
#  'Hopewell, Virginia',
#  'Lexington, Virginia',
#  'Lynchburg, Virginia',
#  'Manassas, Virginia',
#  'Manassas Park, Virginia',
#  'Martinsville, Virginia',
#  'Newport News, Virginia',
#  'Norfolk, Virginia',
#  'Norton, Virginia',
#  'Petersburg, Virginia',
#  'Poquoson, Virginia',
#  'Portsmouth, Virginia',
#  'Radford, Virginia',
#  'Richmond, Virginia',
#  'Roanoke, Virginia',
#  'Salem, Virginia',
# ...

# %%
maine_county = '''Androscoggin
CITIES: Auburn, Lewiston.
TOWNS: Durham, Greene, Leeds, Lisbon, Livermore, Livermore Falls, Mechanic Falls, Minot, Poland, Sabattus, Turner, Wales.


Aroostook
CITIES: Caribou, Presque Isle
TOWNS: Allagash, Amity, Ashland, Bancroft, Blaine, Bridgewater, Castle Hill, Caswell, Chapman, Crystal, Dyer Brook, Eagle Lake, Easton, Fort Fairfield, Fort Kent, Frenchville, Grand Isle, Hamlin, Hammond, Haynesville, Hersey, Hodgdon, Houlton, Island Falls, Limestone, Linneus, Littleton, Ludlow, Madawaska, Mapleton, Mars Hill, Masardis, Merrill, Monticello, New Canada, New Limerick, New Sweden, Oakfield, Orient, Perham, Portage Lake, St. Agatha, St. Francis, Sherman, Smyrna, Stockholm, Van Buren, Wade, Washburn, Westfield, Westmanland, Weston, Woodland.


Cumberland
CITIES: Portland, South Portland, Westbrook
TOWNS: Baldwin, Bridgton, Brunswick, Cape Elizabeth, Casco, Cumberland, Falmouth, Freeport, Gorham, Gray, Harpswell, Harrison, Naples, New Gloucester, North Yarmouth, Pownal, Raymond, Scarborough, Sebago, Standish, Windham, Yarmouth.


Franklin
TOWNS: Avon, Carrabassett Valley, Carthage, Chesterville, Eustis, Farmington, Industry, Jay, Kingfield, Madrid, New Sharon, New Vineyard, Phillips, Rangeley, Strong, Temple, Weld and Wilton.
PLANTATIONS: Coplin, Dallas, Rangeley, Sandy River.


Hancock
CITY: Ellsworth
TOWNS: Amherst, Aurora, Bar Harbor, Blue Hill, Brooklin, Brooksvile, Bucksport, Castine, Cranberry Isles, Dedham, Deer Isle, Eastbrook, Franklin, Frenchboro, Gouldsboro, Great Pond, Hancock, Lamoine, Mariaville, Mount Desert, Orland, Osborn, Otis, Penobscot, Sedgwick, Sorrento, Southwest Harbor, Stonington, Sullivan, Surry, Swans Island, Tremont, Trenton, Verona, Waltham, Winter Harbor.


Kennebec
CITIES: Augusta, Gardiner, Hallowell and Waterville.
TOWNS: Addison, Alexander, Baileyville, Beals, Beddington, Centerville, Charlotte, Cherryfield, Columbia, Columbia Falls, Cooper, Crawford, Cutler, Danforth, Deblois, Dennysville, East Machias, Harrington, Indian Township, Jonesboro, Jonesport, Lubec, Machais, Machiasport, Marshfield, Meddybemps, Milbridge, Northfield, Pembroke, Perry, Princeton, Robbinston, Roque Bluffs, Steuben, Talmadge, Topsfield, Vanceboro, Waite, Wesley, Whiting, Whitneyville.
PLANTATIONS: Baring, Codyville, Grand Lake Stream.


York
CITIES: Biddeford, Saco.
TOWNS: Acton, Alfred, Arundel, Berwick, Buxton, Cornish, Dayton, Eliot, Hollis, Kennebunk, Kennebunkport, Kittery, Lebanon, Limerick, Limington, Lyman, Newfield, North Berwick, Ogunquit, Old Orchard Beach, Parsonsfield, Sanford, Shapleigh, South Berwick, Waterboro, Wells and York.'''

# %%
maine_county_list = maine_county.split("\n\n\n")
maine_county_list
# Out:
# ['Androscoggin\nCITIES: Auburn, Lewiston.\nTOWNS: Durham, Greene, Leeds, Lisbon, Livermore, Livermore Falls, Mechanic Falls, Minot, Poland, Sabattus, Turner, Wales.',
#  'Aroostook\nCITIES: Caribou, Presque Isle\nTOWNS: Allagash, Amity, Ashland, Bancroft, Blaine, Bridgewater, Castle Hill, Caswell, Chapman, Crystal, Dyer Brook, Eagle Lake, Easton, Fort Fairfield, Fort Kent, Frenchville, Grand Isle, Hamlin, Hammond, Haynesville, Hersey, Hodgdon, Houlton, Island Falls, Limestone, Linneus, Littleton, Ludlow, Madawaska, Mapleton, Mars Hill, Masardis, Merrill, Monticello, New Canada, New Limerick, New Sweden, Oakfield, Orient, Perham, Portage Lake, St. Agatha, St. Francis, Sherman, Smyrna, Stockholm, Van Buren, Wade, Washburn, Westfield, Westmanland, Weston, Woodland.',
# ...

# %%
for county in maine_county_list:
    split = re.split("\n|\t", county)
    county = split[0]
    for types in split[1:]:
        for ct in re.split(", | and", types.split(': ')[1].strip(".")):
            city_to_county[(ct.strip(), "ME")] = county + " County"

# %%
city_to_county
# Out:
# {('Bethel', 'CT'): 'Fairfield County',
#  ('Bridgeport', 'CT'): 'Fairfield County',
#  ('Brookfield', 'CT'): 'Fairfield County',
#  ('Danbury', 'CT'): 'Fairfield County',
#  ('Darien', 'CT'): 'Fairfield County',
#  ('Easton', 'CT'): 'Fairfield County',
#  ('Fairfield', 'CT'): 'Fairfield County',
#  ('Greenwich', 'CT'): 'Fairfield County',
#  ('Monroe', 'CT'): 'Fairfield County',
#  ('New Canaan', 'CT'): 'Fairfield County',
#  ('New Fairfield', 'CT'): 'Fairfield County',
#  ('Newtown', 'CT'): 'Fairfield County',
#  ('Norwalk', 'CT'): 'Fairfield County',
#  ('Redding', 'CT'): 'Fairfield County',
#  ('Ridgefield', 'CT'): 'Fairfield County',
#  ('Shelton', 'CT'): 'Fairfield County',
#  ('Sherman', 'CT'): 'Fairfield County',
#  ('Stamford', 'CT'): 'Fairfield County',
#  ('Stratford', 'CT'): 'Fairfield County',
#  ('Trumbull', 'CT'): 'Fairfield County',
#  ('Weston', 'CT'): 'Fairfield County',
#  ('Westport', 'CT'): 'Fairfield County',
#  ('Wilton', 'CT'): 'Fairfield County',
# ...

# %%
for town in [ct for ct in all_weird if ct.split()[-1] == "Maine"]:
    if (town.split(",")[0], "ME") not in city_to_county:
        print(town.split(",")[0])
#     print("yes")

# %%
all_weird = [ct for ct in all_weird if ct.split()[-1] not in ["Connecticut", "Maine"]]
all_weird
# Out:
# ['District of, District of Columbia',
#  'Baltimore, Maryland',
#  'St. Louis, Missouri',
#  'Carson, Nevada',
#  'Alexandria, Virginia',
#  'Bedford, Virginia',
#  'Bristol, Virginia',
#  'Buena Vista, Virginia',
#  'Charlottesville, Virginia',
#  'Chesapeake, Virginia',
#  'Colonial Heights, Virginia',
#  'Covington, Virginia',
#  'Danville, Virginia',
#  'Emporia, Virginia',
#  'Fairfax, Virginia',
#  'Falls Church, Virginia',
#  'Franklin, Virginia',
#  'Fredericksburg, Virginia',
#  'Galax, Virginia',
#  'Hampton, Virginia',
#  'Harrisonburg, Virginia',
#  'Hopewell, Virginia',
#  'Lexington, Virginia',
#  'Lynchburg, Virginia',
#  'Manassas, Virginia',
#  'Manassas Park, Virginia',
#  'Martinsville, Virginia',
#  'Newport News, Virginia',
#  'Norfolk, Virginia',
#  'Norton, Virginia',
#  'Petersburg, Virginia',
#  'Poquoson, Virginia',
#  'Portsmouth, Virginia',
#  'Radford, Virginia',
#  'Richmond, Virginia',
#  'Roanoke, Virginia',
#  'Salem, Virginia',
# ...

# %%
mass_county_list = '''Municipality County
Abington Plymouth
Acton Middlesex
Acushnet Bristol
Adams Berkshire
Agawam Hampden
Alford Berkshire
Allston Suffolk
Amesbury Essex
Amherst Hampshire
Andover Essex
Aquinnah Dukes
Arlington Middlesex
Ashburnham Worcester
Ashby Middlesex
Ashfield Franklin
Ashland Middlesex
Athol Worcester
Attleboro Bristol
Auburn Worcester
Avon Norfolk
Ayer Middlesex
Barnstable Barnstable
Barre Worcester
Becket Berkshire
Bedford Middlesex
Belchertown Hampshire
Bellingham Norfolk
Belmont Middlesex
Berkley Bristol
Berlin Worcester
Bernardston Franklin
Beverly Essex
Billerica Middlesex
Blackstone Worcester
Blandford Hampden
Bolton Worcester
Boston Suffolk
Bourne Barnstable
Boxborough Middlesex
Boxford Essex
Boylston Worcester
Braintree Norfolk
Brewster Barnstable
Municipality County
Bridgewater Plymouth
Brighton Suffolk
Brimfield Hampden
Brockton Plymouth
Brookfield Worcester
Brookline Norfolk
Buckland Franklin
Burlington Middlesex
Cambridge Middlesex
Canton Norfolk
Carlisle Middlesex
Carver Plymouth
Charlemont Franklin
Charlestown Suffolk
Charlton Worcester
Chatham Barnstable
Chelmsford Middlesex
Chelsea Suffolk
Cheshire Berkshire
Chester Hampden
Chesterfield Hampshire
Chicopee Hampden
Chilmark Dukes
Clarksburg Berkshire
Clinton Worcester
Cohasset Norfolk
Colrain Franklin
Concord Middlesex
Conway Franklin
Cummington Hampshire
Dalton Berkshire
Danvers Essex
Dartmouth Bristol
Dedham Norfolk
Deerfield Franklin
Dennis Barnstable
Dighton Bristol
Dorchester Suffolk
Douglas Worcester
Dover Norfolk
Dracut Middlesex
Dudley Worcester
# Ashland, Middlesex
# Athol, Worcester
# Attleboro, Bristol
# Auburn, Worcester
# Avon, Norfolk
# Ayer, Middlesex
# Barnstable, Barnstable
# Barre, Worcester
# Becket, Berkshire
# Bedford, Middlesex
# Belchertown, Hampshire
# Bellingham, Norfolk
# Belmont, Middlesex
# Berkley, Bristol
# Berlin, Worcester
# Bernardston, Franklin
# Beverly, Essex
# Billerica, Middlesex
# Blackstone, Worcester
# Blandford, Hampden
# Bolton, Worcester
# Boston, Suffolk
# Bourne, Barnstable
# Boxborough, Middlesex
# Boxford, Essex
# Boylston, Worcester
# Braintree, Norfolk
# Brewster, Barnstable
# Bridgewater, Plymouth
# Brighton, Suffolk
# Brimfield, Hampden
# Brockton, Plymouth
# Brookfield, Worcester
# ...

# %%
for town in [ct for ct in all_weird if ct.split(", ")[-1] == "Massachusetts"]:
    if (town.split(",")[0], "MA") not in city_to_county:
        city_to_county[(town.split(",")[0], "MA")] = city_to_county[(" ".join(town.split(",")[0].split()[:-1]), "MA")]
        print(town.split(",")[0])
#     print("yes")

# %%
city_to_county
# Out:
# {('Bethel', 'CT'): 'Fairfield County',
#  ('Bridgeport', 'CT'): 'Fairfield County',
#  ('Brookfield', 'CT'): 'Fairfield County',
#  ('Danbury', 'CT'): 'Fairfield County',
#  ('Darien', 'CT'): 'Fairfield County',
#  ('Easton', 'CT'): 'Fairfield County',
#  ('Fairfield', 'CT'): 'Fairfield County',
#  ('Greenwich', 'CT'): 'Fairfield County',
#  ('Monroe', 'CT'): 'Fairfield County',
#  ('New Canaan', 'CT'): 'Fairfield County',
#  ('New Fairfield', 'CT'): 'Fairfield County',
#  ('Newtown', 'CT'): 'Fairfield County',
#  ('Norwalk', 'CT'): 'Fairfield County',
#  ('Redding', 'CT'): 'Fairfield County',
#  ('Ridgefield', 'CT'): 'Fairfield County',
#  ('Shelton', 'CT'): 'Fairfield County',
#  ('Sherman', 'CT'): 'Fairfield County',
#  ('Stamford', 'CT'): 'Fairfield County',
#  ('Stratford', 'CT'): 'Fairfield County',
#  ('Trumbull', 'CT'): 'Fairfield County',
#  ('Weston', 'CT'): 'Fairfield County',
#  ('Westport', 'CT'): 'Fairfield County',
#  ('Wilton', 'CT'): 'Fairfield County',
# ...

# %%
all_weird = [ct for ct in all_weird if ct.split()[-1] not in ["Connecticut", "Maine", "Massachusetts"]]
all_weird
# Out:
# ['District of, District of Columbia',
#  'Baltimore, Maryland',
#  'St. Louis, Missouri',
#  'Carson, Nevada',
#  'Alexandria, Virginia',
#  'Bedford, Virginia',
#  'Bristol, Virginia',
#  'Buena Vista, Virginia',
#  'Charlottesville, Virginia',
#  'Chesapeake, Virginia',
#  'Colonial Heights, Virginia',
#  'Covington, Virginia',
#  'Danville, Virginia',
#  'Emporia, Virginia',
#  'Fairfax, Virginia',
#  'Falls Church, Virginia',
#  'Franklin, Virginia',
#  'Fredericksburg, Virginia',
#  'Galax, Virginia',
#  'Hampton, Virginia',
#  'Harrisonburg, Virginia',
#  'Hopewell, Virginia',
#  'Lexington, Virginia',
#  'Lynchburg, Virginia',
#  'Manassas, Virginia',
#  'Manassas Park, Virginia',
#  'Martinsville, Virginia',
#  'Newport News, Virginia',
#  'Norfolk, Virginia',
#  'Norton, Virginia',
#  'Petersburg, Virginia',
#  'Poquoson, Virginia',
#  'Portsmouth, Virginia',
#  'Radford, Virginia',
#  'Richmond, Virginia',
#  'Roanoke, Virginia',
#  'Salem, Virginia',
# ...

# %%
nh_county_list = '''Acworth	Sullivan	UVLSRPC
Albany	Carroll	NCC
Alexandria	Grafton	LRPC
Allenstown	Merrimack	CNHRPC
Alstead	Cheshire	SwRPC
Alton	Belknap	LRPC
Amherst	Hillsborough	NRPC
Andover	Merrimack	LRPC
Antrim	Hillsborough	SwRPC
Ashland	Grafton	LRPC
Atkinson	Rockingham	RPC
Auburn	Rockingham	SNHPC
Barnstead	Belknap	LRPC
Barrington	Strafford	SRPC
Bartlett	Carroll	NCC
Bath	Grafton	NCC
Bedford	Hillsborough	SHNPC
Belmont	Belknap	LRPC
Bennington	Hillsborough	SwRPC
Benton	Grafton	NCC
Berlin	Coos	NCC
Bethlehem	Grafton	NCC
Boscawen	Merrimack	CNHRPC
Bow	Merrimack	CNHRPC
Bradford	Merrimack	CNHRPC
Brentwood	Rockingham	RPC
Bridgewater	Grafton	LRPC
Bristol	Grafton	LRPC
Brookfield	Carroll	SRPC
Brookline	Hillsborough	NRPC
Campton	Grafton	NCC
Canaan	Grafton	UVLSRPC
Candia	Rockingham	SNHPC
Canterbury	Merrimack	CNHRPC
Carroll	Coos	NCC
Center Harbor	Belknap	LRPC
Charlestown	Sullivan	UVLSRPC
Chatham	Carroll	NCC
Chester	Rockingham	SNHPC
Chesterfield	Cheshire	SwRPC
Chichester	Merrimack	CNHRPC
Claremont	Sullivan	UVLSRPC
Clarksville	Coos	NCC
Colebrook	Coos	NCC
Columbia	Coos	NCC
Concord	Merrimack	CNHRPC
Conway	Carroll	NCC
Cornish	Sullivan	UVLSRPC
Croydon	Sullivan	UVLSRPC
Dalton	Coos	NCC
Danbury	Merrimack	LRPC
Danville	Rockingham	RPC
Deerfield	Rockingham	SNHPC
Deering	Hillsborough	CNHRPC
Derry	Rockingham	SNHPC
Dorchester	Grafton	UVLSRPC
Dover	Strafford	SRPC
Dublin	Cheshire	SwRPC
Dummer	Coos	NCC
Dunbarton	Merrimack	CNHRPC
Durham	Strafford	SRPC
East Kingston	Rockingham	RPC
Easton	Grafton	NCC
Eaton	Carroll	NCC
Effingham	Carroll	LRPC
Ellsworth	Grafton	NCC
Enfield	Grafton	UVLSRPC
Epping	Rockingham	RPC
Epsom	Merrimack	CNHRPC
Errol	Coos	NCC
Exeter	Rockingham	RPC
Farmington	Strafford	SRPC
Fitzwilliam	Cheshire	SwRPC
Francestown	Hillsborough	SNHPC
Franconia	Grafton	NCC
Franklin	Merrimack	LRPC
Freedom	Carroll	LRPC
Fremont	Rockingham	RPC
Gilford	Belknap	LRPC
Gilmanton	Belknap	LRPC
Gilsum	Cheshire	SwRPC
Goffstown	Hillsborough	SNHPC
Gorham	Coos	NCC
Goshen	Sullivan	UVLSRPC
Grafton	Grafton	UVLSRPC
Grantham	Sullivan	UVLSRPC
Greenfield	Hillsborough	SwRPC
Greenland	Rockingham	RPC
Greenville	Hillsborough	SwRPC
Groton	Grafton	NCC
Hampstead	Rockingham	RPC
Hampton	Rockingham	RPC
Hampton Falls	Rockingham	RPC
Hancock	Hillsborough	SwRPC
Hanover	Grafton	UVLSRPC
Harrisville	Cheshire	SwRPC
Hart's Location	Carroll	NCC
Haverhill	Grafton	NCC
Hebron	Grafton	LRPC
Henniker	Merrimack	CNHRPC
Hill	Merrimack	LRPC
Hillsborough	Hillsborough	CNHRPC
Hinsdale	Cheshire	SwRPC
Holderness	Grafton	LRPC
Hollis	Hillsborough	NRPC
Hooksett	Merrimack	SNHPC
Hopkinton	Merrimack	CNHRPC
Hudson	Hillsborough	NRPC
Jackson	Carroll	NCC
Jaffrey	Cheshire	SwRPC
Jefferson	Coos	NCC
Keene	Cheshire	SwRPC
Kensington	Rockingham	RPC
Kingston	Rockingham	RPC
Laconia	Belknap	LRPC
Lancaster	Coos	NCC
Landaff	Grafton	NCC
Langdon	Sullivan	SwRPC
Lebanon	Grafton	UVLSRPC
Lee	Strafford	SRPC
Lempster	Sullivan	UVLSRPC
Lincoln	Grafton	NCC
Lisbon	Grafton	NCC
Litchfield	Hillsborough	NRPC
Littleton	Grafton	NCC
Londonderry	Rockingham	SNHPC
Loudon	Merrimack	CNHRPC
Lyman	Grafton	NCC
Lyme	Grafton	UVLSRPC
Lyndeborough	Hillsborough	NRPC
Madbury	Strafford	SRPC
Madison	Carroll	NCC
Manchester	Hillsborough	SNHPC
Marlborough	Cheshire	SwRPC
Marlow	Cheshire	SwRPC
Mason	Hillsborough	NRPC
Meredith	Belknap	LRPC
Merrimack	Hillsborough	NRPC
Middleton	Strafford	SRPC
Milan	Coos	NCC
Milford	Hillsborough	NRPC
Milton	Strafford	SRPC
Monroe	Grafton	NCC
Mont Vernon	Hillsborough	NRPC
Moultonborough	Carroll	LRPC
Nashua	Hillsborough	NRPC
Nelson	Cheshire	SwRPC
New Boston	Hillsborough	SNHPC
New Castle	Rockingham	RPC
New Durham	Strafford	SRPC
New Hampton	Belknap	LRPC
New Ipswich	Hillsborough	SwRPC
New London	Merrimack	UVLSRPC
Newbury	Merrimack	UVLSRPC
Newfields	Rockingham	RPC
Newington	Rockingham	RPC
Newmarket	Rockingham	SRPC
Newport	Sullivan	UVLSRPC
Newton	Rockingham	RPC
North Hampton	Rockingham	RPC
Northfield	Merrimack	LRPC
Northumberland	Coos	NCC
Northwood	Rockingham	SRPC
Nottingham	Rockingham	SRPC
Orange	Grafton	UVLSRPC
Orford	Grafton	UVLSRPC
Ossipee	Carroll	LRPC
Pelham	Hillsborough	NRPC
Pembroke	Merrimack	CNHRPC
Peterborough	Hillsborough	SwRPC
Piermont	Grafton	UVLSRPC
Pittsburg	Coos	NCC
Pittsfield	Merrimack	CNHRPC
Plainfield	Sullivan	UVLSRPC
Plaistow	Rockingham	RPC
Plymouth	Grafton	LRPC
Portsmouth	Rockingham	RPC
Randolph	Coos	NCC
Raymond	Rockingham	RPC
Richmond	Cheshire	SwRPC
Rindge	Cheshire	SwRPC
Rochester	Strafford	SRPC
Rollinsford	Strafford	SRPC
Roxbury	Cheshire	SwRPC
Rumney	Grafton	NCC
Rye	Rockingham	RPC
Salem	Rockingham	RPC
Salisbury	Merrimack	CNHRPC
Sanbornton	Belknap	LRPC
Sandown	Rockingham	RPC
Sandwich	Carroll	LRPC
Seabrook	Rockingham	RPC
Sharon	Hillsborough	SwRPC
Shelburne	Coos	NCC
Somersworth	Strafford	SRPC
South Hampton	Rockingham	RPC
Springfield	Sullivan	UVLSRPC
Stark	Coos	NCC
Stewartstown	Coos	NCC
Stoddard	Cheshire	SwRPC
Strafford	Strafford	SRPC
Stratford	Coos	NCC
Stratham	Rockingham	RPC
Sugar Hill	Grafton	NCC
Sullivan	Cheshire	SwRPC
Sunapee	Sullivan	UVLSRPC
Surry	Cheshire	SwRPC
Sutton	Merrimack	CNHRPC
Swanzey	Cheshire	SwRPC
Tamworth	Carroll	LRPC
Temple	Hillsborough	SwRPC
Thornton	Grafton	NCC
Tilton	Belknap	LRPC
Troy	Cheshire	SwRPC
Tuftonboro	Carroll	LRPC
Unity	Sullivan	UVLSRPC
Wakefield	Carroll	SRPC
Walpole	Cheshire	SwRPC
Warner	Merrimack	CNHRPC
Warren	Grafton	NCC
Washington	Sullivan	UVLSRPC
Waterville Valley	Grafton	NCC
Weare	Hillsborough	SNHPC
Webster	Merrimack	CNHRPC
Wentworth	Grafton	NCC
Westmoreland	Cheshire	SwRPC
Whitefield	Coos	NCC
Wilmot	Merrimack	UVLSRPC
Wilton	Hillsborough	NRPC
Winchester	Cheshire	SwRPC
Windham	Rockingham	SNHPC
Windsor	Hillsborough	SwRPC
Wolfeboro	Carroll	LRPC
Woodstock	Grafton	NCC'''

# %%
nh_townlist = nh_county_list.split("\n")
for t in nh_townlist:
    temp = t.split("	")
    print(temp[0] + ", " + temp[1])
    city_to_county[(temp[0], "NH")] = temp[1] + " County"
# Out:
# Acworth, Sullivan
# Albany, Carroll
# Alexandria, Grafton
# Allenstown, Merrimack
# Alstead, Cheshire
# Alton, Belknap
# Amherst, Hillsborough
# Andover, Merrimack
# Antrim, Hillsborough
# Ashland, Grafton
# Atkinson, Rockingham
# Auburn, Rockingham
# Barnstead, Belknap
# Barrington, Strafford
# Bartlett, Carroll
# Bath, Grafton
# Bedford, Hillsborough
# Belmont, Belknap
# Bennington, Hillsborough
# Benton, Grafton
# Berlin, Coos
# Bethlehem, Grafton
# Boscawen, Merrimack
# Bow, Merrimack
# Bradford, Merrimack
# Brentwood, Rockingham
# Bridgewater, Grafton
# Bristol, Grafton
# Brookfield, Carroll
# Brookline, Hillsborough
# Campton, Grafton
# Canaan, Grafton
# Candia, Rockingham
# Canterbury, Merrimack
# Carroll, Coos
# Center Harbor, Belknap
# Charlestown, Sullivan
# Chatham, Carroll
# Chester, Rockingham
# Chesterfield, Cheshire
# Chichester, Merrimack
# Claremont, Sullivan
# Clarksville, Coos
# Colebrook, Coos
# Columbia, Coos
# Concord, Merrimack
# Conway, Carroll
# ...

# %%
city_to_county
# Out:
# {('Bethel', 'CT'): 'Fairfield County',
#  ('Bridgeport', 'CT'): 'Fairfield County',
#  ('Brookfield', 'CT'): 'Fairfield County',
#  ('Danbury', 'CT'): 'Fairfield County',
#  ('Darien', 'CT'): 'Fairfield County',
#  ('Easton', 'CT'): 'Fairfield County',
#  ('Fairfield', 'CT'): 'Fairfield County',
#  ('Greenwich', 'CT'): 'Fairfield County',
#  ('Monroe', 'CT'): 'Fairfield County',
#  ('New Canaan', 'CT'): 'Fairfield County',
#  ('New Fairfield', 'CT'): 'Fairfield County',
#  ('Newtown', 'CT'): 'Fairfield County',
#  ('Norwalk', 'CT'): 'Fairfield County',
#  ('Redding', 'CT'): 'Fairfield County',
#  ('Ridgefield', 'CT'): 'Fairfield County',
#  ('Shelton', 'CT'): 'Fairfield County',
#  ('Sherman', 'CT'): 'Fairfield County',
#  ('Stamford', 'CT'): 'Fairfield County',
#  ('Stratford', 'CT'): 'Fairfield County',
#  ('Trumbull', 'CT'): 'Fairfield County',
#  ('Weston', 'CT'): 'Fairfield County',
#  ('Westport', 'CT'): 'Fairfield County',
#  ('Wilton', 'CT'): 'Fairfield County',
# ...

# %%
all_weird = [ct for ct in all_weird if ct.split(", ")[-1] not in ["Connecticut", "Maine", "Massachusetts", "New Hampshire"]]
all_weird
# Out:
# ['District of, District of Columbia',
#  'Baltimore, Maryland',
#  'St. Louis, Missouri',
#  'Carson, Nevada',
#  'Alexandria, Virginia',
#  'Bedford, Virginia',
#  'Bristol, Virginia',
#  'Buena Vista, Virginia',
#  'Charlottesville, Virginia',
#  'Chesapeake, Virginia',
#  'Colonial Heights, Virginia',
#  'Covington, Virginia',
#  'Danville, Virginia',
#  'Emporia, Virginia',
#  'Fairfax, Virginia',
#  'Falls Church, Virginia',
#  'Franklin, Virginia',
#  'Fredericksburg, Virginia',
#  'Galax, Virginia',
#  'Hampton, Virginia',
#  'Harrisonburg, Virginia',
#  'Hopewell, Virginia',
#  'Lexington, Virginia',
#  'Lynchburg, Virginia',
#  'Manassas, Virginia',
#  'Manassas Park, Virginia',
#  'Martinsville, Virginia',
#  'Newport News, Virginia',
#  'Norfolk, Virginia',
#  'Norton, Virginia',
#  'Petersburg, Virginia',
#  'Poquoson, Virginia',
#  'Portsmouth, Virginia',
#  'Radford, Virginia',
#  'Richmond, Virginia',
#  'Roanoke, Virginia',
#  'Salem, Virginia',
# ...

# %%
ri_county_list = '''Bristol County - Barrington, Bristol, Warren

Kent County - Coventry, East Greenwich, Warwick, West Greenwich, West Warwick

Newport County - Jamestown, Little Compton, Middletown, Newport, Portsmouth, Tiverton

Providence County - Burrillville, Central Falls, Cranston, Cumberland, East Providence, Foster, Glocester, Johnston, Lincoln, North Providence, North Smithfield, Pawtucket, Providence, Scituate, Smithfield, Woonsocket

Washington County - Charlestown, Exeter, Hopkinton, Narragansett, New Shoreham, North Kingstown, Richmond, South Kingstown, Westerly'''

# %%
ri_counties = ri_county_list.split("\n\n")
ri_counties
for ct in ri_counties:
    ri_counties = ct.split(" - ")
    county = ri_counties[0]
    for town in ri_counties[1].split(", "):
        print(town + ",  " + county)
        city_to_county[(town, "RI")] = county + " County"
# Out:
# Barrington,  Bristol County
# Bristol,  Bristol County
# Warren,  Bristol County
# Coventry,  Kent County
# East Greenwich,  Kent County
# Warwick,  Kent County
# West Greenwich,  Kent County
# West Warwick,  Kent County
# Jamestown,  Newport County
# Little Compton,  Newport County
# Middletown,  Newport County
# Newport,  Newport County
# Portsmouth,  Newport County
# Tiverton,  Newport County
# Burrillville,  Providence County
# Central Falls,  Providence County
# Cranston,  Providence County
# Cumberland,  Providence County
# East Providence,  Providence County
# Foster,  Providence County
# Glocester,  Providence County
# Johnston,  Providence County
# Lincoln,  Providence County
# North Providence,  Providence County
# North Smithfield,  Providence County
# Pawtucket,  Providence County
# Providence,  Providence County
# Scituate,  Providence County
# Smithfield,  Providence County
# Woonsocket,  Providence County
# Charlestown,  Washington County
# Exeter,  Washington County
# ...

# %%
print(city_to_county)
# Out:
# {('Bethel', 'CT'): 'Fairfield County', ('Bridgeport', 'CT'): 'Fairfield County', ('Brookfield', 'CT'): 'Fairfield County', ('Danbury', 'CT'): 'Fairfield County', ('Darien', 'CT'): 'Fairfield County', ('Easton', 'CT'): 'Fairfield County', ('Fairfield', 'CT'): 'Fairfield County', ('Greenwich', 'CT'): 'Fairfield County', ('Monroe', 'CT'): 'Fairfield County', ('New Canaan', 'CT'): 'Fairfield County', ('New Fairfield', 'CT'): 'Fairfield County', ('Newtown', 'CT'): 'Fairfield County', ('Norwalk', 'CT'): 'Fairfield County', ('Redding', 'CT'): 'Fairfield County', ('Ridgefield', 'CT'): 'Fairfield County', ('Shelton', 'CT'): 'Fairfield County', ('Sherman', 'CT'): 'Fairfield County', ('Stamford', 'CT'): 'Fairfield County', ('Stratford', 'CT'): 'Fairfield County', ('Trumbull', 'CT'): 'Fairfield County', ('Weston', 'CT'): 'Fairfield County', ('Westport', 'CT'): 'Fairfield County', ('Wilton', 'CT'): 'Fairfield County', ('Avon', 'CT'): 'Hartford County', ('Berlin', 'CT'): 'Hartford County', ('Bloom
# ...

# %%
for town in [ct for ct in all_weird if ct.split(", ")[-1] == "Rhode Island"]:
    if (town.split(",")[0], "RI") not in city_to_county:
#         city_to_county[(town.split(",")[0], "MA")] = city_to_county[(" ".join(town.split(",")[0].split()[:-1]), "RI")]
        print(town.split(",")[0])
#     print("yes")

# %%
all_weird = [ct for ct in all_weird if ct.split(", ")[-1] not in ["Connecticut", "Maine", "Massachusetts", "New Hampshire", "Rhode Island"]]
all_weird
# Out:
# ['District of, District of Columbia',
#  'Baltimore, Maryland',
#  'St. Louis, Missouri',
#  'Carson, Nevada',
#  'Alexandria, Virginia',
#  'Bedford, Virginia',
#  'Bristol, Virginia',
#  'Buena Vista, Virginia',
#  'Charlottesville, Virginia',
#  'Chesapeake, Virginia',
#  'Colonial Heights, Virginia',
#  'Covington, Virginia',
#  'Danville, Virginia',
#  'Emporia, Virginia',
#  'Fairfax, Virginia',
#  'Falls Church, Virginia',
#  'Franklin, Virginia',
#  'Fredericksburg, Virginia',
#  'Galax, Virginia',
#  'Hampton, Virginia',
#  'Harrisonburg, Virginia',
#  'Hopewell, Virginia',
#  'Lexington, Virginia',
#  'Lynchburg, Virginia',
#  'Manassas, Virginia',
#  'Manassas Park, Virginia',
#  'Martinsville, Virginia',
#  'Newport News, Virginia',
#  'Norfolk, Virginia',
#  'Norton, Virginia',
#  'Petersburg, Virginia',
#  'Poquoson, Virginia',
#  'Portsmouth, Virginia',
#  'Radford, Virginia',
#  'Richmond, Virginia',
#  'Roanoke, Virginia',
#  'Salem, Virginia',
# ...

# %%
vt_county_list = '''Addison:Addison, Cavendish:Windsor, Greensboro:Orleans,
Albany:Orleans, Charleston:Orleans, Groton:Caledonia,
Alburgh:Grand Isle, Charlotte:Chittenden, Guildhall:Essex,
Andover:Windsor, Chelsea:Orange, Guilford:Windham,
Arlington:Bennington, Chester:Windsor, Halifax:Windham,
Athens:Windham, Chittenden:Rutland, Hancock:Addison,
Averill:Essex, Clarendon:Rutland, Hardwick:Caledonia,
Avery's gore:Essex, Colchester:Chittenden, Hartford:Windsor,
Bakersfield:Franklin, Concord:Essex, Hartland:Windsor,
Baltimore:Windsor, Corinth:Orange, Highgate:Franklin,
Barnard:Windsor, Cornwall:Addison, Hinesburg:Chittenden,
Barnet:Caledonia, Coventry:Orleans, Holland:Orleans,
Barre:Washington, Craftsbury:Orleans, Hubbardton:Rutland,
Barre:Washington, Danby:Rutland, Huntington:Chittenden,
Barton:Orleans, Danville:Caledonia, Hyde Park:Lamoille,
Belvidere:Lamoille, Derby:Orleans, Ira:Rutland,
Bennington:Bennington, Dorset:Bennington, Irasburg:Orleans,
Benson:Rutland, Dover:Windham, Isle La Motte:Grand Isle,,
Berkshire:Franklin, Dummerston:Windham, Jamaica:Windham,
Berlin:Washington, Duxbury:Washington, Jay:Orleans,
Bethel:Windsor, East Haven:Essex, Jericho:Chittenden,
Bloomfield:Essex, East Montpelier:Washington, Johnson:Lamoille,
Bolton:Chittenden, Eden:Lamoille, Killington:Rutland,
Bradford:Orange, Elmore:Lamoille, Kirby:Caledonia,
Braintree:Orange, Enosburgh:Franklin, Landgrove:Bennington,
Brandon:Rutland, Essex:Chittenden, Leicester:Addison,
Brattleboro:Windham, Fair Haven:Rutland, Lemington:Essex,
Bridgewater:Windsor, Fairfax:Franklin, Lewis:Essex,
Bridport:Addison, Fairfield:Franklin, Lincoln:Addison,
Brighton:Essex, Fairlee:Orange, Londonderry:Windham,
Bristol:Addison, Fayston:Washington, Lowell:Orleans,
Brookfield:Orange, Ferdinand:Essex, Ludlow:Windsor,
Brookline:Windham, Ferrisburgh:Addison, Lunenburg:Essex,
Brownington:Orleans, Fletcher:Franklin, Lyndon:Caledonia,
Brunswick:Essex, Franklin:Franklin, Maidstone:Essex,
Buel's gore:Chittenden, Georgia:Franklin, Manchester:Bennington,
Burke:Caledonia, Glastenbury:Bennington, Marlboro:Windham,
Burlington:Chittenden, Glover:Orleans, Marshfield:Washington,
Cabot:Washington, Goshen:Addison, Mendon:Rutland,
Calais:Washington, Grafton:Windham, Middlebury:Addison,
Cambridge:Lamoille, Granby:Essex, Middlesex:Washington,
["Connecticut", "Maine", "Massachusetts", "New Hampshire", "Rhode Island", "Vermont"]]
all_weird
# Out:
# ['District of, District of Columbia',
#  'Baltimore, Maryland',
#  'St. Louis, Missouri',
#  'Carson, Nevada',
#  'Alexandria, Virginia',
#  'Bedford, Virginia',
#  'Bristol, Virginia',
#  'Buena Vista, Virginia',
#  'Charlottesville, Virginia',
#  'Chesapeake, Virginia',
#  'Colonial Heights, Virginia',
#  'Covington, Virginia',
#  'Danville, Virginia',
#  'Emporia, Virginia',
#  'Fairfax, Virginia',
#  'Falls Church, Virginia',
#  'Franklin, Virginia',
#  'Fredericksburg, Virginia',
#  'Galax, Virginia',
#  'Hampton, Virginia',
#  'Harrisonburg, Virginia',
#  'Hopewell, Virginia',
#  'Lexington, Virginia',
#  'Lynchburg, Virginia',
#  'Manassas, Virginia',
#  'Manassas Park, Virginia',
#  'Martinsville, Virginia',
#  'Newport News, Virginia',
#  'Norfolk, Virginia',
#  'Norton, Virginia',
#  'Petersburg, Virginia',
#  'Poquoson, Virginia',
#  'Portsmouth, Virginia',
#  'Radford, Virginia',
#  'Richmond, Virginia',
#  'Roanoke, Virginia',
#  'Salem, Virginia',
# ...

# %%
print(city_to_county)
# Out:
# {('Bethel', 'CT'): 'Fairfield County', ('Bridgeport', 'CT'): 'Fairfield County', ('Brookfield', 'CT'): 'Fairfield County', ('Danbury', 'CT'): 'Fairfield County', ('Darien', 'CT'): 'Fairfield County', ('Easton', 'CT'): 'Fairfield County', ('Fairfield', 'CT'): 'Fairfield County', ('Greenwich', 'CT'): 'Fairfield County', ('Monroe', 'CT'): 'Fairfield County', ('New Canaan', 'CT'): 'Fairfield County', ('New Fairfield', 'CT'): 'Fairfield County', ('Newtown', 'CT'): 'Fairfield County', ('Norwalk', 'CT'): 'Fairfield County', ('Redding', 'CT'): 'Fairfield County', ('Ridgefield', 'CT'): 'Fairfield County', ('Shelton', 'CT'): 'Fairfield County', ('Sherman', 'CT'): 'Fairfield County', ('Stamford', 'CT'): 'Fairfield County', ('Stratford', 'CT'): 'Fairfield County', ('Trumbull', 'CT'): 'Fairfield County', ('Weston', 'CT'): 'Fairfield County', ('Westport', 'CT'): 'Fairfield County', ('Wilton', 'CT'): 'Fairfield County', ('Avon', 'CT'): 'Hartford County', ('Berlin', 'CT'): 'Hartford County', ('Bloom
# ...

# %%
result = {}
for ct in city_to_county:
    result[str(ct)] = str(city_to_county[ct])
print(result)
# Out:
# {"('Bethel', 'CT')": 'Fairfield County', "('Bridgeport', 'CT')": 'Fairfield County', "('Brookfield', 'CT')": 'Fairfield County', "('Danbury', 'CT')": 'Fairfield County', "('Darien', 'CT')": 'Fairfield County', "('Easton', 'CT')": 'Fairfield County', "('Fairfield', 'CT')": 'Fairfield County', "('Greenwich', 'CT')": 'Fairfield County', "('Monroe', 'CT')": 'Fairfield County', "('New Canaan', 'CT')": 'Fairfield County', "('New Fairfield', 'CT')": 'Fairfield County', "('Newtown', 'CT')": 'Fairfield County', "('Norwalk', 'CT')": 'Fairfield County', "('Redding', 'CT')": 'Fairfield County', "('Ridgefield', 'CT')": 'Fairfield County', "('Shelton', 'CT')": 'Fairfield County', "('Sherman', 'CT')": 'Fairfield County', "('Stamford', 'CT')": 'Fairfield County', "('Stratford', 'CT')": 'Fairfield County', "('Trumbull', 'CT')": 'Fairfield County', "('Weston', 'CT')": 'Fairfield County', "('Westport', 'CT')": 'Fairfield County', "('Wilton', 'CT')": 'Fairfield County', "('Avon', 'CT')": 'Hartford Count
# ...

# %%
for in_cty in all_weird:
    cty = in_cty.split(", ")[0]
    state = state_codes[in_cty.split(", ")[1]]
    print(f"(\"{cty}\", \"{state}\"): \" County\",")
# Out:
# ("District of", "DC"): " County",
# ("Baltimore", "MD"): " County",
# ("St. Louis", "MO"): " County",
# ("Carson", "NV"): " County",
# ("Alexandria", "VA"): " County",
# ("Bedford", "VA"): " County",
# ("Bristol", "VA"): " County",
# ("Buena Vista", "VA"): " County",
# ("Charlottesville", "VA"): " County",
# ("Chesapeake", "VA"): " County",
# ("Colonial Heights", "VA"): " County",
# ("Covington", "VA"): " County",
# ("Danville", "VA"): " County",
# ("Emporia", "VA"): " County",
# ("Fairfax", "VA"): " County",
# ("Falls Church", "VA"): " County",
# ("Franklin", "VA"): " County",
# ("Fredericksburg", "VA"): " County",
# ("Galax", "VA"): " County",
# ("Hampton", "VA"): " County",
# ("Harrisonburg", "VA"): " County",
# ("Hopewell", "VA"): " County",
# ("Lexington", "VA"): " County",
# ("Lynchburg", "VA"): " County",
# ("Manassas", "VA"): " County",
# ("Manassas Park", "VA"): " County",
# ("Martinsville", "VA"): " County",
# ("Newport News", "VA"): " County",
# ...

# %%
ind_cities_to_counties = {
    ("District of", "DC"): " County",
    ("Baltimore", "MD"): " County",
    ("St. Louis", "MO"): " County",
    ("Carson", "NV"): " County",
    ("Alexandria", "VA"): "Alexandria County",
    ("Bedford", "VA"): "Bedford County",
    ("Bristol", "VA"): "Washington County",
    ("Buena Vista", "VA"): "Rockbridge County",
    ("Charlottesville", "VA"): "Albermarle County",
    ("Chesapeake", "VA"): " County",
    ("Colonial Heights", "VA"): " County",
    ("Covington", "VA"): " County",
    ("Danville", "VA"): " County",
    ("Emporia", "VA"): " County",
    ("Fairfax", "VA"): " County",
    ("Falls Church", "VA"): " County",
    ("Franklin", "VA"): " County",
    ("Fredericksburg", "VA"): " County",
    ("Galax", "VA"): " County",
    ("Hampton", "VA"): " County",
    ("Harrisonburg", "VA"): " County",
    ("Hopewell", "VA"): " County",
    ("Lexington", "VA"): " County",
    ("Lynchburg", "VA"): " County",
    ("Manassas", "VA"): " County",
    ("Manassas Park", "VA"): " County",
    ("Martinsville", "VA"): " County",
    ("Newport News", "VA"): " County",
    ("Norfolk", "VA"): " County",
    ("Norton", "VA"): " County",
    ("Petersburg", "VA"): " County",
    ("Poquoson", "VA"): " County",
    ("Portsmouth", "VA"): " County",
    ("Radford", "VA"): " County",
    ("Richmond", "VA"): " County",
    ("Roanoke", "VA"): " County",
    ("Salem", "VA"): " County",
    ("Staunton", "VA"): " County",
    ("Suffolk", "VA"): " County",
    ("Virginia Beach", "VA"): " County",
    ("Waynesboro", "VA"): " County",
    ("Williamsburg", "VA"): " County",
    ("Winchester", "VA"): " County",
}
